# %%
spark.sql("USE CATALOG med_atlas_ai")
spark.sql("USE SCHEMA default")

# %%
for table in [
    "med_atlas_ai.default.facility_facts",
    "med_atlas_ai.default.facility_records",
    "med_atlas_ai.default.regional_insights"
]:
    print(f"Schema for {table}:")
    df = spark.table(table)
    for field in df.schema.fields:
        print(f"{field.name}: {field.dataType}")
    print()

# %%
# %sql
ALTER TABLE med_atlas_ai.default.facility_factsmed_atlas_ai.default.facility_facts
SET TBLPROPERTIES (delta.enableChangeDataFeed = true);
